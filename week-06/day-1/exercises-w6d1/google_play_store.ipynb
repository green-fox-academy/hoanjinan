# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('googleplaystore.csv', parse_dates = ["Last Updated"], encoding='utf-8')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
# Perform EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10840 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null int64
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10841 non-null object
# Genres            10840 non-null object
# Last Updated      10841 non-null datetime64[ns]
# Current Ver       10833 non-null object
# Android Ver       10839 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
# Perform EDA
df.shape
# Out:
# (10841, 13)

# %%
# Perform EDA
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Perform EDA
df.head
# Out:
# <bound method NDFrame.head of                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
# Perform EDA
df.describe(include = 'all')
# Out:
#            App Category       Rating       Reviews                Size  \
# count    10841    10840  9367.000000  1.084100e+04               10841
# unique    9660       33          NaN           NaN                 461
# top     ROBLOX   FAMILY          NaN           NaN  Varies with device
# freq         9     1972          NaN           NaN                1695
# first      NaN      NaN          NaN           NaN                 NaN
# last       NaN      NaN          NaN           NaN                 NaN
# mean       NaN      NaN     4.191513  4.441119e+05                 NaN
# std        NaN      NaN     0.515735  2.927629e+06                 NaN
# min        NaN      NaN     1.000000  0.000000e+00                 NaN
# 25%        NaN      NaN     4.000000  3.800000e+01                 NaN
# 50%        NaN      NaN     4.300000  2.094000e+03                 NaN
# 75%        NaN      NaN     4.500000  5.476800e+04                 NaN
# ...

# %%
# List down what we know about the app called "Pixel Draw - Number Art Coloring Book"
app_pixel_draw = df[df["App"] == "Pixel Draw - Number Art Coloring Book"]
app_pixel_draw
# Out:
#                                      App        Category  Rating  Reviews  \
# 4  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3      967
#
#    Size  Installs  Type Price Content Rating                   Genres  \
# 4  2.8M  100,000+  Free     0       Everyone  Art & Design;Creativity
#
#   Last Updated Current Ver Android Ver
# 4   2018-06-20         1.1  4.4 and up

# %%
# List down what we know about apps called "Pixel Draw - Number Art Coloring Book", "Beauty Selfie Camera", "BestCam Selfie-selfie, beauty camera, photo editor"
df[df["App"].isin(["Pixel Draw - Number Art Coloring Book", "Beauty Selfie Camera", "BestCam Selfie-selfie, beauty camera, photo editor"])]
# Out:
#                                                    App        Category  \
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# 101  BestCam Selfie-selfie, beauty camera, photo ed...          BEAUTY
# 103                               Beauty Selfie Camera          BEAUTY
#
#      Rating  Reviews  Size  Installs  Type Price Content Rating  \
# 4       4.3      967  2.8M  100,000+  Free     0       Everyone
# 101     3.9     1739   21M  500,000+  Free     0       Everyone
# 103     4.2     2225   52M  500,000+  Free     0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver
# 4    Art & Design;Creativity   2018-06-20         1.1    4.4 and up
# 101                   Beauty   2018-07-12       1.0.6  4.0.3 and up
# 103                   Beauty   2018-02-28         1.6    4.1 and up

# %%
# View all the apps listed before the "Mandala Coloring Book"
df[df.index < df[df["App"] == "Mandala Coloring Book"].index[0]]
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
# List only the ratings of all the apps between 'Paper flowers instructions' and 'Text on Photo - Fonteee'
df[(df.index >= df[df["App"] == "Paper flowers instructions"].index[0]) & (df.index <= df[df["App"] == "Text on Photo - Fonteee"].index[0])]["Rating"]
# Out:
# 5     4.4
# 6     3.8
# 7     4.1
# 8     4.4
# 9     4.7
# 10    4.4
# Name: Rating, dtype: float64

# %%
# List all the columns between 'Size' and 'Content Rating'
df.loc[:,"Size":"Content Rating"]
# Out:
#                      Size     Installs  Type Price Content Rating
# 0                     19M      10,000+  Free     0       Everyone
# 1                     14M     500,000+  Free     0       Everyone
# 2                    8.7M   5,000,000+  Free     0       Everyone
# 3                     25M  50,000,000+  Free     0           Teen
# 4                    2.8M     100,000+  Free     0       Everyone
# 5                    5.6M      50,000+  Free     0       Everyone
# 6                     19M      50,000+  Free     0       Everyone
# 7                     29M   1,000,000+  Free     0       Everyone
# 8                     33M   1,000,000+  Free     0       Everyone
# 9                    3.1M      10,000+  Free     0       Everyone
# 10                    28M   1,000,000+  Free     0       Everyone
# 11                    12M   1,000,000+  Free     0       Everyone
# 12                    20M  10,000,000+  Free     0           Teen
# ...

# %%
# What is the average rating of apps in the store?
df["Rating"].mean()
# Out:
# 4.1915127575531175

# %%
# What is the ratio of free vs paid?
# Needs improving
# df["Price"].convert_objects(convert_numeric=True).dropna()
# df["Type"].value_counts(normalize = True)
# df["Type"].value_counts()

#New way of doing that - Cheers Clair!
free = df[df["Type"] == "Free"]["Type"].count()
paid = df[df["Type"] == "Paid"]["Type"].count()
ratio = free / paid
ratio
# Out:
# 12.55

# %%
# What is the highest amount of Reviews an app received? And the lowest?
# df["Reviews"].astype(float)
# df.sort_values(by = ["Reviews"], ascending = False)
# Highest
df[df["Reviews"] == df["Reviews"].max()]
# Out:
#            App Category  Rating   Reviews                Size        Installs  \
# 2544  Facebook   SOCIAL     4.1  78158306  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres Last Updated         Current Ver  \
# 2544  Free     0           Teen  Social   2018-08-03  Varies with device
#
#              Android Ver
# 2544  Varies with device

# %%
# Lowest
df[df["Reviews"] == df["Reviews"].min()]
# Out:
#                                                      App             Category  \
# 478                                    Truth or Dare Pro               DATING
# 479      Private Dating, Hide App- Blue for PrivacyHider               DATING
# 621                                   Dating White Girls               DATING
# 623                                         Geeks Dating               DATING
# 627                                   CAM5678 Video Chat               DATING
# 628                              Video chat live advices               DATING
# 630                                    Pet Lovers Dating               DATING
# 632                                         Latin Dating               DATING
# 635                                          Wifi Mingle               DATING
# 639                                HOW TO ASK A GIRL OUT               DATING
# 641                           The DJ - Match with People               DATING
# ...

# %%
# What are the ten most recently updated apps?
df.sort_values(by = ["Last Updated"], ascending = False).iloc[:10]
# Out:
#                                                      App            Category  \
# 10712                              Lalafo Pulsuz Elanlar            SHOPPING
# 10209       Video Downloader For FB: Save FB Videos 2018               TOOLS
# 10408                            Shoot Hunter-Gun Killer                GAME
# 10718                                         BankNordik             FINANCE
# 10760                                    Fast Tract Diet  HEALTH_AND_FITNESS
# 10502                         Fun Kid Racing - Motocross              FAMILY
# 10301  FD Calculator (EMI, SIP, RD & Loan Eligilibility)             FINANCE
# 10373                                             FG VOC            BUSINESS
# 10790                             HipChat - beta version       COMMUNICATION
# 8749                                Monster Fishing 2018              SPORTS
#
#        Rating  Reviews                Size     Installs  Type  Price  \
# ...

# %%
# Find apps, that is in the top 25% of apps based on ratings and were updated in the last two months of dataset.
from datetime import timedelta
twenty_five_percent = int(df.shape[0] * 0.25)
top_rating = df.sort_values(by = ["Rating"], ascending = False).iloc[:twenty_five_percent]
sorted_date = top_rating.sort_values(by = ["Last Updated"], ascending = False)
last_two_months = sorted_date["Last Updated"].max() - timedelta(days = 60)
sorted_date[sorted_date["Last Updated"] > last_two_months]
# Out:
#                                                      App             Category  \
# 9827                      ET Telecom from Economic Times   NEWS_AND_MAGAZINES
# 10373                                             FG VOC             BUSINESS
# 9597                      Dragonplay™ Poker Texas Holdem                 GAME
# 9853                        Amino: Communities and Chats               SOCIAL
# 9677   Masha and The Bear Jam Day Match 3 games for kids               FAMILY
# 3840                                Sygic Car Navigation  MAPS_AND_NAVIGATION
# 9089                                             DYPSOET               FAMILY
# 10301  FD Calculator (EMI, SIP, RD & Loan Eligilibility)              FINANCE
# 10199                              Friendly for Facebook               SOCIAL
# 9620                        Hello English: Learn English               FAMILY
# 9579          Live Hold’em Pro Poker - Free Casino Games                 GAME
# ...

# %%
# Which app not to download? - Find an app which takes the most space on your phone, but is rated poorly (define poorly)?
storage = []
for i in df["Size"]:
    if i.endswith("M"):
       storage.append(i)
storage.sort()
print(storage)
# df[df["Size"] != "Varies with device"].sort_values(by = ["Size"], ascending = False)
# Out:
# ['1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '1.0M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.1M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.2M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.3M', '1.4M', '1.4M', '1.4M', '1.4M', '1.4M', '1.4M', '1.4M', '1.4M', '1.4M', '1.4M
# ...
