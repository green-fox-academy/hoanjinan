# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('la_bike.csv', index_col=0)

df.head()
# Out:
#           Duration               Start Time                 End Time  \
# Trip ID
# 18222186     15060  2017-01-19T17:05:00.000  2017-01-19T21:16:00.000
# 9518671      77160  2016-10-09T14:37:00.000  2016-10-10T12:03:00.000
# 20444932     86400  2017-02-18T10:15:00.000  2017-02-20T15:20:00.000
# 20905031     18840  2017-02-27T12:26:00.000  2017-02-27T17:40:00.000
# 21031476     86400  2017-02-27T20:26:00.000  2017-03-01T09:49:00.000
#
#           Starting Station ID  Starting Station Latitude  \
# Trip ID
# 18222186               3031.0                  34.044701
# 9518671                   NaN                        NaN
# 20444932               3026.0                  34.063179
# 20905031               3023.0                  34.050911
# 21031476               3008.0                  34.046612
#
#           Starting Station Longitude  Ending Station ID  \
# Trip ID
# 18222186                 -118.252441             3000.0
# 9518671                          NaN             3000.0
# ...
